# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-SARDAR/FMML_Assignment-2022/blob/main/Module8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-29 11:20:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   170MB/s    in 0.4s
#
# 2023-05-29 11:20:16 (170 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 17997  cs/0003039v1  The US Data Encryption Standard, DES for short...    cs
# 7705   1802.09511v1  High-dimensional time series data exist in num...  stat
# 10189  1711.06299v1  Pandemic influenza has the epidemic potential ...    cs
# 26636  1611.05418v3  This paper proposes a new method, that we call...    cs
# 38103   0903.2792v3  In this work, we suggest a parameterized stati...    cs
# ...             ...                                                ...   ...
# 33285   0902.1040v2  This paper presents a generalization of the "w...    cs
# 25580  1510.02927v1  Understanding and predicting the human visual ...    cs
# 12225  1710.08167v1  Visual exploration of high-dimensional real-va...  stat
# 5667   1604.04960v1  The variational autoencoder (VAE) is a generat...  stat
# 20208  1504.02027v1  This paper presents two variants of penta-valu...    cs
#
#                                                    title  year  \
# 17997  DES: a Challenge Problem for Nonmonotonic Reas...  2000
# 7705   Missing Data in Sparse Transition Matrix Estim...  2018
# 10189  Bayesian Best-Arm Identification for Selecting...  2017
# 26636    VisualBackProp: efficient visualization of CNNs  2016
# 38103            Thermodynamics of Information Retrieval  2009
# ...                                                  ...   ...
# 33285  Fast solving of Weighted Pairing Least-Squares...  2009
# 25580  DeepFix: A Fully Convolutional Neural Network ...  2015
# 12225  Interactive Visual Data Exploration with Subje...  2017
# 5667   Gaussian Copula Variational Autoencoders for M...  2016
# 20208   The Neutrosophic Entropy and its Five Components  2015
#
#                                                 keywords
# 17997  [encryption, interesting, benchmark, nonmonoto...
# 7705   [dimensional, healthcare, neuroscience, unavoi...
# 10189  [influenza, potential, preventive, vaccination...
# 26636  [visualbackprop, visualizing, contribute, pred...
# 38103  [parameterized, statistical, frequency, occurr...
# ...                                                  ...
# 33285  [generalization, rectangular, alignment, defic...
# 25580  [understanding, predicting, attentional, mecha...
# 12225  [exploration, dimensional, fundamental, explor...
# 5667   [variational, autoencoder, generative, continu...
# 20208  [representation, neutrosophic, extension, kauf...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 17997    [encryption, interesting, benchmark, nonmonoto...
# 7705     [dimensional, healthcare, neuroscience, unavoi...
# 10189    [influenza, potential, preventive, vaccination...
# 26636    [visualbackprop, visualizing, contribute, pred...
# 38103    [parameterized, statistical, frequency, occurr...
#                                ...
# 10999    [estimation, potentially, dimensional, structu...
# 19842    [diagnostic, diagnostic, inference, multimembe...
# 29138    [automated, detection, important, challenging,...
# 15551    [fundamental, processing, determining, referen...
# 2328     [unsupervised, estimation, graphical, correspo...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8836 words.
# Out of those 4547 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3ff8c430-3ae9-4528-8dbf-e9d78df08934" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ff8c430-3ae9-4528-8dbf-e9d78df08934")) {                    Plotly.newPlot(                        "3ff8c430-3ae9-4528-8dbf-e9d78df08934",                        [{"x":["optimized","implementation","challenge","formalizations","encodings","interesting","understand","extending","encryption","competitive","relevance","industrial","generated","representation","specifications","comparable","outperform","computational","properties","benchmark","reasoning","customized","nonmonotonic","semantics","transition","theoretical","autoregressive","applicable","neuroscience","important","dependent","unavoidable","estimating","healthcare","regression","interactions","innovation","processes","observation","covariates","interdependent","characterizing","satisfies","regularized","statistics","perspective","partially","dynamical","estimation","dimensional","concentration","challenges","underlying","previously","additionally","experimental","intensive","efficient","preventive","evaluations","epidemiological","essential","algorithms","identification","selecting","consequently","specified","contribute","confidence","distribution","demonstrate","effective","knowledge","strategies","predominant","determining","experiments","potential","evaluation","statistic","literature","challenging","realistic","recommendation","therefore","computationally","individual","technique","mitigation","influenza","magnitude","visualizing","convolutional","identifies","arguments","developed","collaboratively","presented","empirical","intuition","plausibility","simultaneously","inference","agreement","visualization","applications","prediction","information","favorably","furthermore","exploring","irrelevant","computations","propagation","theoretically","debugging","predictions","differentiating","differences","statistical","traditional","advantages","quantities","constructing","thermodynamic","corresponding","different","thermodynamics","partition","occurrences","parameterized","retrieval","frequency","parameters","pathology","reduction","classification","coefficients","component","artificial","detecting","extraction","decomposition","principal","classifier","performance","diagnosis","evaluating","successfully","detection","annotated","classifying","locations","preprocessing","classifications","demonstrated","recognizes","promising","classifiers","investigated","automatic","segmentation","generalization","scalability","significant","hyperplanes","algorithm","clustering","distributes","dimensions","addressed","interpretable","iterative","subroutine","typically","clinically","motivates","population","researchers","prioritizes","encouraging","clinicians","precision","approaches","prioritize","optimization","personalize","variables","demographic","treatment","supervised","hypertension","vulnerable","subgroups","similarity","optimality","mathematical","placement","established","diversity"],"y":[49,125,175,2,10,65,76,33,4,123,42,19,181,386,6,90,86,288,207,220,127,10,10,74,33,177,4,56,9,322,72,1,57,8,150,74,12,95,54,1,1,19,19,44,49,74,51,15,204,208,7,116,102,83,73,403,18,390,1,64,2,62,603,90,48,29,40,33,42,221,549,250,327,107,4,30,598,159,244,4,120,291,68,25,142,81,122,260,3,2,62,9,380,21,19,206,3,196,180,18,8,125,209,20,23,435,217,724,20,171,38,20,31,73,44,3,78,3,61,146,176,79,15,50,3,120,754,2,28,15,21,113,46,251,7,115,514,30,107,128,77,138,59,30,167,919,37,52,83,331,75,35,47,22,8,124,6,107,126,49,175,174,110,41,237,1,849,146,4,49,41,27,71,3,103,4,17,54,71,2,11,5,85,410,3,337,4,129,8,31,216,2,16,4,147,24,58,9,50,43],"type":"bar"},{"x":["optimized","implementation","challenge","formalizations","encoding ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4547,), (4547, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.825

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Human</span> <span style=''>Pose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>using</span> <span style=''>Global</span> <span style=''>and</span> <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Normalization</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.43);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>positions</span> <span style=''>of</span> <span style=''>human</span> <span style=''>joints</span> <span style=''>ie</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>articulated</span> <span style=''>pose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>Recent</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>model</span> <span style=''>two</span> <span style=''>key</span> <span style=''>issues</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.484304932735426);'>detection</span> <span style=''>and</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>configuration</span> <span style='background-color:rgba(0, 255, 0, 0.6875);'>refinement</span> <span style=''>together</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.6450216450216449);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>mainly</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>configuration</span> <span style='background-color:rgba(0, 255, 0, 0.6875);'>refinement</span> <span style=''>by</span> <span style=''>reducing</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058822);'>variations</span> <span style=''>of</span> <span style=''>human</span> <span style=''>poses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistically</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scattered</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>relative</span> <span style='background-color:rgba(0, 255, 0, 0.5161290322580646);'>locations</span> <span style=''>of</span> <span style=''>joints</span> <span style=''>eg</span> <span style=''>the</span> <span style=''>left</span> <span style=''>wrist</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>nearly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uniformly</span> <span style=''>in</span> <span style=''>a</span> <span style=''>circular</span> <span style=''>area</span> <span style=''>around</span> <span style=''>the</span> <span style=''>left</span> <span style=''>shoulder)</span> <span style=''>makes</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6450216450216449);'>convolutional</span> <span style=''>spatial</span> <span style=''>models</span> <span style=''>hard</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Testing</span> <span style=''>for</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relevance</span> <span style=''>The</span> <span style=''>HARVEST</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>and</span> <span style=''>a</span> <span style=''>very</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proportion</span> <span style=''>of</span> <span style=''>relevant</span> <span style=''>features</span> <span style=''>poses</span> <span style=''>a</span> <span style=''>severe</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>to</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>(HARVEST)</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style=''>to</span> <span style=''>apply</span> <span style=''>albeit</span> <span style=''>somewhat</span> <span style=''>computer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intensive</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>pre</span> <span style=''>screen</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>features</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>those</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentially</span> <span style=''>useful</span> <span style=''>The</span> <span style=''>basic</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>each</span> <span style=''>feature</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>many</span> <span style=''>random</span> <span style=''>subsets</span> <span style=''>of</span> <span style=''>other</span> <span style=''>features</span> <span style=''>HARVEST</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicated</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>irrelevant</span> <span style=''>feature</span> <span style=''>can</span> <span style=''>add</span> <span style=''>no</span> <span style=''>real</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regardless</span> <span style=''>of</span> <span style=''>which</span> <span style=''>other</span> <span style=''>features</span> <span style=''>are</span> <span style=''>included</span> <span style=''>in</span> <span style=''>the</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Motivated</span> <span style=''>by</span> <span style=''>this</span> <span style=''>idea</span> <span style=''>we</span> <span style=''>have</span> <span style=''>derived</span> <span style=''>a</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Manifold</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Geodesic</span> <span style=''>Minimal</span> <span style=''>Spanning</span> <span style=''>Trees</span> <br/><br/><span style=''>In</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>one</span> <span style=''>seeks</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>a</span> <span style=''>smooth</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style=''>surface</span> <span style=''>ie</span> <span style=''>a</span> <span style=''>manifold</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>a</span> <span style=''>higher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style=''>linear</span> <span style=''>vector</span> <span style=''>space</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>measured</span> <span style=''>sample</span> <span style=''>points</span> <span style=''>on</span> <span style=''>the</span> <span style=''>surface</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>closely</span> <span style=''>related</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.43);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manifolds</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.3705583756345179);'>dimension</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style=''>entropy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>points</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>view</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>points</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>realizations</span> <span style=''>of</span> <span style=''>an</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.6031746031746033);'>multivariate</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supported</span> <span style=''>on</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>smooth</span> <span style=''>manifold</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.7272727272727274);'>geometrical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>approach</span> <span style=''>called</span> <span style=''>the</span> <span style=''>geodesic</span> <span style=''>minimal</span> <span style=''>spanning</span> <span style=''>tree</span> <span style=''>(GMST)</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obtaining</span> <span style='background-color:rgba(255, 0, 0, 0.46666666666666673);'>asymptotically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>of</span> <span style=''>the</span> <span style=''>manifold</span> <span style='background-color:rgba(255, 0, 0, 0.3705583756345179);'>dimension</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Renyi</span> <span style=''>alpha</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Comprehensive</span> <span style=''>Feature</span> <span style=''>Based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Landscape</span> <span style=''>Analysis</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Continuous</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>Problems</span> <span style=''>Using</span> <span style=''>the</span> <span style=''>R</span> <span style=''>Package</span> <span style=''>flacco</span> <br/><br/><span style=''>Choosing</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>optimizer(s)</span> <span style=''>out</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>portfolio</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>and</span> <span style=''>complex</span> <span style=''>task</span> <span style=''>It</span> <span style=''>gets</span> <span style=''>even</span> <span style=''>worse</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>unknown</span> <span style=''>ie</span> <span style=''>so</span> <span style=''>called</span> <span style=''>Black</span> <span style=''>Box</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>In</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploratory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Landscape</span> <span style=''>Analysis</span> <span style=''>(ELA)</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sophisticated</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>landscapes</span> <span style=''>of</span> <span style=''>such</span> <span style=''>problems</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style=''>values</span> <span style=''>before</span> <span style=''>actually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>task</span> <span style=''>itself</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantageous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unfortunately</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13904899135446686)
# 	processing (0.10951008645533142)
# 	challenging (0.10482708933717579)
# 	architecture (0.09402017291066282)
# 	detection (0.11923631123919308)
# 	information (0.260806916426513)
# 	experimental (0.1451729106628242)
# 	different (0.2716138328530259)
# 	convolutional (0.13688760806916425)
# 	recognition (0.14769452449567724)
#
# Some Statistics words are:
# 	stochastic (0.13191699604743082)
# 	algorithm (0.38883399209486164)
# 	theoretical (0.15167984189723321)
# 	variables (0.14278656126482214)
# 	statistical (0.15019762845849802)
# 	distribution (0.17984189723320157)
# 	estimation (0.1793478260869565)
# 	dimensional (0.18231225296442688)
# 	inference (0.19268774703557312)
# 	regression (0.18132411067193677)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cee1414b-dff7-43b7-a933-21b0cc16be77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cee1414b-dff7-43b7-a933-21b0cc16be77")) {                    Plotly.newPlot(                        "cee1414b-dff7-43b7-a933-21b0cc16be77",                        [{"x":["optimized","implementation","challenge","formalizations","encodings","interesting","understand","extending","encryption","competitive","relevance","industrial","generated","representation","specifications","comparable","outperform","computational","properties","benchmark","reasoning","customized","nonmonotonic","semantics","transition","theoretical","autoregressive","applicable","neuroscience","important","dependent","unavoidable","estimating","healthcare","regression","interactions","innovation","processes","observation","covariates","interdependent","characterizing","satisfies","regularized","statistics","perspective","partially","dynamical","estimation","dimensional","concentration","challenges","underlying","previously","additionally","experimental","intensive","efficient","preventive","evaluations","epidemiological","essential","algorithms","identification","selecting","consequently","specified","contribute","confidence","distribution","demonstrate","effective","knowledge","strategies","predominant","determining","experiments","potential","evaluation","statistic","literature","challenging","realistic","recommendation","therefore","computationally","individual","technique","mitigation","influenza","magnitude","visualizing","convolutional","identifies","arguments","developed","collaboratively","presented","empirical","intuition","plausibility","simultaneously","inference","agreement","visualization","applications","prediction","information","favorably","furthermore","exploring","irrelevant","computations","propagation","theoretically","debugging","predictions","differentiating","differences","statistical","traditional","advantages","quantities","constructing","thermodynamic","corresponding","different","thermodynamics","partition","occurrences","parameterized","retrieval","frequency","parameters","pathology","reduction","classification","coefficients","component","artificial","detecting","extraction","decomposition","principal","classifier","performance","diagnosis","evaluating","successfully","detection","annotated","classifying","locations","preprocessing","classifications","demonstrated","recognizes","promising","classifiers","investigated","automatic","segmentation","generalization","scalability","significant","hyperplanes","algorithm","clustering","distributes","dimensions","addressed","interpretable","iterative","subroutine","typically","clinically","motivates","population","researchers","prioritizes","encouraging","clinicians","precision","approaches","prioritize","optimization","personalize","variables","demographic","treatment","supervised","hypertension","vulnerable","subgroups","similarity","optimality","mathematical","placement","established","diversity","dependency","principle","orderings","framework","maximizes","maximization","principles","dependencies","evolution","competing","implications","syntactic","theoretic","minimization","predictability","synthesizing","localization","improvements","particular","available","increases","correlation","destructive","alignment","predefined","contextual","inferring","formalized","computation","inferences","entailment","determined","feasibility","inferencing","describing","represented","implement","mechanism","incorporating","transformation","transform","identical","coordinate","structures","alternating","numerical","computing","reasonable","extremely","measurements","direction","moderately","variation","multipliers","undersampl ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	particulars
# 	requisite
# 	solvation
# 	anonymization
# 	nonlinearly
# 	cheminformatics
# 	dependences
# 	identically
# 	gracefully
# 	blockwise
# 	biophysical
# 	inhibited
# 	archetypes
# 	nomination
# 	reflectivity
# 	cytometry
# 	stagewise
# 	substantiate
# 	transports
# 	marginalize
# Some words which never appear in Statistics papers:
# 	formalizations
# 	encryption
# 	specifications
# 	nonmonotonic
# 	epidemiological
# 	prioritizes
# 	prioritize
# 	personalize
# 	hypertension
# 	predictability
# 	destructive
# 	inferencing
# 	redistribution
# 	dempsters
# 	smarandache
# 	combinational
# 	kinematic
# 	volumetric
# 	animation
# 	synthesizer

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.095304423190021e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7866666666666666

# %% [markdown]
# ---
